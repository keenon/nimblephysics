# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
real = np.genfromtxt(f'timeplots/cartpole_naive_real_0.csv',delimiter=',')
identified = np.genfromtxt(f'timeplots/cartpole_naive_identified_0.csv', delimiter = ',')

# %%
real.shape
# Out:
# (188, 2)

# %%
identified.shape
# Out:
# (188, 2)

# %%
plt.plot(real[:,0],color='orange',label = "real")
plt.plot(identified[:,0],color='', label = "identified")
plt.title("Pole Mass")
plt.legend()
